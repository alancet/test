# %% [markdown]
# # Comprehensive data exploration with Python
#
#
# https://www.kaggle.com/pmarcelino/comprehensive-data-exploration-with-python/notebook
#
# - this kernel is not easy to read because of his sentence...
# - so i will skip it and read others

# %%
#invite people for the Kaggle party
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
#bring in the six packs
df_train = pd.read_csv('../input/train.csv')

# %%
#check the decoration
df_train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df_train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
df_train.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
#                   ...
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# KitchenQual       object
# TotRmsAbvGrd       int64
# Functional        object
# Fireplaces         int64
# ...

# %%
df_train.SalePrice.describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
sns.distplot(df_train.SalePrice)

# %%
df_train.MSSubClass.value_counts()
# Out:
# 20     536
# 60     299
# 50     144
# 120     87
# 30      69
# 160     63
# 70      60
# 80      58
# 90      52
# 190     30
# 85      20
# 75      16
# 45      12
# 180     10
# 40       4
# Name: MSSubClass, dtype: int64

# %%
df_train.groupby("MSSubClass").SalePrice.describe()
# Out:
#             count           mean            std       min       25%       50%  \
# MSSubClass
# 20          536.0  185224.811567   78782.189967   35311.0  132500.0  159250.0
# 30           69.0   95829.724638   24857.110083   34900.0   81000.0   99900.0
# 40            4.0  156125.000000   75747.799748   79500.0  119625.0  142500.0
# 45           12.0  108591.666667   20231.723889   76000.0   94125.0  107500.0
# 50          144.0  143302.972222   54851.983707   37900.0  114125.0  132000.0
# 60          299.0  239948.501672   86579.909966  129000.0  185000.0  215200.0
# 70           60.0  166772.416667   58206.545762   40000.0  128000.0  156000.0
# 75           16.0  192437.500000  100556.762577  101000.0  125625.0  163500.0
# 80           58.0  169736.551724   38197.808771  107000.0  147250.0  166500.0
# 85           20.0  147810.000000   19629.942220  123000.0  134350.0  140750.0
# 90           52.0  133541.076923   27833.249197   82000.0  118375.0  135980.0
# ...

# %%
sns.swarmplot(x="MSSubClass", y="SalePrice", data=df_train)

# %%
sns.violinplot(x="MSSubClass", y="SalePrice", data=df_train)

# %%
df_train.MSZoning.value_counts()
# Out:
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64

# %%
df_train.groupby("MSZoning").SalePrice.describe()
# Out:
#            count           mean           std       min        25%       50%  \
# MSZoning
# C (all)     10.0   74528.000000  33791.092031   34900.0   43998.25   74700.0
# FV          65.0  214014.061538  52369.662067  144152.0  174000.00  205950.0
# RH          16.0  131558.375000  35714.118435   76000.0  106150.00  136500.0
# RL        1151.0  191004.994787  80766.341319   39300.0  137700.00  174000.0
# RM         218.0  126316.830275  48521.689833   37900.0  100000.00  120500.0
#
#                75%       max
# MSZoning
# C (all)    98332.0  133900.0
# FV        250000.0  370878.0
# RH        148608.5  200000.0
# RL        224700.0  755000.0
# RM        140000.0  475000.0

# %%
sns.boxplot(x="MSZoning", y="SalePrice", data=df_train)

# %%
sns.violinplot(x="MSZoning", y="SalePrice", data=df_train)

# %%
df_train.LotArea.describe()
# Out:
# count      1460.000000
# mean      10516.828082
# std        9981.264932
# min        1300.000000
# 25%        7553.500000
# 50%        9478.500000
# 75%       11601.500000
# max      215245.000000
# Name: LotArea, dtype: float64

# %%
sns.jointplot(x="LotArea", y="SalePrice", 
              data=df_train, kind="kde")

# %%
df_train.Street.value_counts()
# Out:
# Pave    1454
# Grvl       6
# Name: Street, dtype: int64

# %%
df_train.groupby("Street").SalePrice.describe()
# Out:
#          count           mean           std      min       25%       50%  \
# Street
# Grvl       6.0  130190.500000  65446.253991  55993.0   88250.0  114250.0
# Pave    1454.0  181130.538514  79446.597317  34900.0  130000.0  163000.0
#
#              75%       max
# Street
# Grvl    169650.0  228950.0
# Pave    214000.0  755000.0

# %%
df_train.Alley.value_counts()
# Out:
# Grvl    50
# Pave    41
# Name: Alley, dtype: int64

# %%
df_train.LotShape.value_counts()
# Out:
# Reg    925
# IR1    484
# IR2     41
# IR3     10
# Name: LotShape, dtype: int64

# %%
df_train.groupby("LotShape").SalePrice.describe()
# Out:
#           count           mean           std       min       25%       50%  \
# LotShape
# IR1       484.0  206101.665289  85858.489559   52000.0  150000.0  189000.0
# IR2        41.0  239833.365854  99669.427362  110000.0  175000.0  221000.0
# IR3        10.0  216036.500000  82540.334855   73000.0  167875.0  203570.0
# Reg       925.0  164754.818378  69673.427215   34900.0  120000.0  146000.0
#
#                75%       max
# LotShape
# IR1       239000.0  755000.0
# IR2       250000.0  538000.0
# IR3       265000.0  375000.0
# Reg       188000.0  582933.0

# %%
def printDescPriceRelation(featureName):
    print(df_train[featureName].value_counts())
    print(df_train.groupby(featureName).SalePrice.describe())

# %%
printDescPriceRelation("LotShape")
# Out:
# Reg    925
# IR1    484
# IR2     41
# IR3     10
# Name: LotShape, dtype: int64
#           count           mean           std       min       25%       50%  \
# LotShape
# IR1       484.0  206101.665289  85858.489559   52000.0  150000.0  189000.0
# IR2        41.0  239833.365854  99669.427362  110000.0  175000.0  221000.0
# IR3        10.0  216036.500000  82540.334855   73000.0  167875.0  203570.0
# Reg       925.0  164754.818378  69673.427215   34900.0  120000.0  146000.0
#
#                75%       max
# LotShape
# IR1       239000.0  755000.0
# IR2       250000.0  538000.0
# IR3       265000.0  375000.0
# Reg       188000.0  582933.0

# %%
printDescPriceRelation("OverallQual")
# Out:
# 5     397
# 6     374
# 7     319
# 8     168
# 4     116
# 9      43
# 3      20
# 10     18
# 2       3
# 1       2
# Name: OverallQual, dtype: int64
#              count           mean            std       min       25%  \
# OverallQual
# 1              2.0   50150.000000   15344.217152   39300.0   44725.0
# 2              3.0   51770.333333   14254.200796   35311.0   47655.5
# 3             20.0   87473.750000   24688.567399   37900.0   75500.0
# 4            116.0  108420.655172   29022.003886   34900.0   88000.0
# 5            397.0  133523.347607   27107.330927   55993.0  118000.0
# 6            374.0  161603.034759   36090.182933   76000.0  139125.0
# 7            319.0  207716.423197   44466.259414   82500.0  179470.0
# 8            168.0  274735.535714   63898.902253  122000.0  234557.5
# 9             43.0  367513.023256   81278.174849  239000.0  318980.5
# 10            18.0  438588.388889  159785.491058  160000.0  349375.0
#
#                   50%       75%       max
# ...

# %%
printDescPriceRelation("OverallCond")
# Out:
# 5    821
# 6    252
# 7    205
# 8     72
# 4     57
# 3     25
# 9     22
# 2      5
# 1      1
# Name: OverallCond, dtype: int64
#              count           mean            std       min       25%  \
# OverallCond
# 1              1.0   61000.000000            NaN   61000.0   61000.0
# 2              5.0  141986.400000  141342.813488   67000.0   76500.0
# 3             25.0  101929.400000   44852.490403   35311.0   76000.0
# 4             57.0  120438.438596   38922.525907   40000.0   92900.0
# 5            821.0  203146.914738   85117.319416   34900.0  144000.0
# 6            252.0  153961.591270   60737.969824   37900.0  124375.0
# 7            205.0  158145.487805   53468.189431   79900.0  123500.0
# 8             72.0  155651.736111   52375.144681   84500.0  125375.0
# 9             22.0  216004.545455   96485.974689  110500.0  143500.0
#
#                   50%       75%       max
# OverallCond
# 1             61000.0   61000.0   61000.0
# ...

# %%
printDescPriceRelation("SaleCondition")
# Out:
# Normal     1198
# Partial     125
# Abnorml     101
# Family       20
# Alloca       12
# AdjLand       4
# Name: SaleCondition, dtype: int64
#                 count           mean            std       min        25%  \
# SaleCondition
# Abnorml         101.0  146526.623762   82796.213395   34900.0  104000.00
# AdjLand           4.0  104125.000000   26135.464411   81000.0   81750.00
# Alloca           12.0  167377.416667   84460.527502   55993.0  116383.25
# Family           20.0  149600.000000   47820.002421   82500.0  115500.00
# Normal         1198.0  175202.219533   69713.636280   39300.0  130000.00
# Partial         125.0  272291.752000  103696.404119  113000.0  193879.00
#
#                     50%       75%       max
# SaleCondition
# Abnorml        130000.0  172500.0  745000.0
# AdjLand        104000.0  126375.0  127500.0
# Alloca         148145.0  202043.0  359100.0
# Family         140500.0  170250.0  259000.0
# Normal         160000.0  205000.0  755000.0
# ...

# %%
df_train.SalePrice.skew()
# Out:
# 1.8828757597682129

# %%
df_train.SalePrice.kurt()
# Out:
# 6.536281860064529

# %%
sns.jointplot(x="GrLivArea", y="SalePrice", data=df_train)

# %%
sns.jointplot(x="TotalBsmtSF", y="SalePrice", data=df_train)

# %%
sns.pairplot(df_train[["SalePrice",
                       "GrLivArea",
                       "TotalBsmtSF"
                      ]])

# %%
sns.boxplot(x="OverallQual", y="SalePrice", data=df_train)

# %%
sns.violinplot(x="OverallQual", y="SalePrice", data=df_train)

# %%
sns.boxplot(x="YearBuilt", y="SalePrice", data=df_train)

# %%
df_train.corr()
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %%
corrmat = df_train.corr()
f, ax = plt.subplots(figsize=(24,18))
sns.heatmap(corrmat, 
#            annot=True,           
           )

# %%
corrmat
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %%
corrmat.nlargest(5, 'SalePrice')
# Out:
#                    Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# SalePrice   -0.021917   -0.084284     0.351799  0.263843     0.790982
# OverallQual -0.028365    0.032628     0.251646  0.105806     1.000000
# GrLivArea    0.008273    0.074853     0.402797  0.263116     0.593007
# GarageCars   0.016570   -0.040110     0.285691  0.154871     0.600671
# GarageArea   0.017634   -0.098672     0.344997  0.180403     0.562022
#
#              OverallCond  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# SalePrice      -0.077856   0.522897      0.507101    0.477493    0.386420
# OverallQual    -0.091932   0.572323      0.550684    0.411876    0.239666
# GrLivArea      -0.079686   0.199010      0.287389    0.390857    0.208171
# GarageCars     -0.185758   0.537850      0.420622    0.364204    0.224054
# GarageArea     -0.151521   0.478954      0.371600    0.373066    0.296970
#
#                ...      WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# ...

# %%
#saleprice correlation matrix
k = 10 #number of variables for heatmap
cols = corrmat.nlargest(k, 'SalePrice')['SalePrice'].index
cm = np.corrcoef(df_train[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %%
corrmat.nlargest(k, 'SalePrice')['SalePrice']
# Out:
# SalePrice       1.000000
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# Name: SalePrice, dtype: float64

# %%
corrmat.nlargest(k, 'SalePrice')['SalePrice'].index
# Out:
# Index(['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea',
#        'TotalBsmtSF', '1stFlrSF', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt'],
#       dtype='object')

# %%
f, ax = plt.subplots(figsize=(12,9))
sns.heatmap(df_train[cols].corr(), annot=True)

# %%
corrmat.nlargest(100, 'SalePrice')['SalePrice']
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# GarageYrBlt      0.486362
# MasVnrArea       0.477493
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# LotFrontage      0.351799
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# Id              -0.021917
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# ...
